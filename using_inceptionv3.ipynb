# %%
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K

# create the base pre-trained model
model = InceptionV3(weights='imagenet' , include_top=False ,classes = 10)
# Out:
# Using TensorFlow backend.

# %%
print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_3 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# conv2d_189 (Conv2D)              (None, None, None, 32 864         input_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_189 (BatchNo (None, None, None, 32 96          conv2d_189[0][0]
# ____________________________________________________________________________________________________
# activation_189 (Activation)      (None, None, None, 32 0           batch_normalization_189[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
x = model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x) 
x = Dense(10 , activation='softmax')(x) 
new_model = Model(input=model.input, output=x)
# Out:
# /home/a95/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   """

# %%
print(new_model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_3 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# conv2d_189 (Conv2D)              (None, None, None, 32 864         input_3[0][0]
# ____________________________________________________________________________________________________
# batch_normalization_189 (BatchNo (None, None, None, 32 96          conv2d_189[0][0]
# ____________________________________________________________________________________________________
# activation_189 (Activation)      (None, None, None, 32 0           batch_normalization_189[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
# In resnet model  i made false for 2 layers  (to make learning fast here)
for layer in model.layers[:5]:
    layer.trainable = False

# %%
import get_Train_Validation_set
train_data = get_Train_Validation_set.get_train_set()
# Out:
# (45000, 224, 224, 3)

# %%
print(train_data[0].shape)
# Out:
# (45000, 224, 224, 3)

# %%
print(Y_dict)
# Out:
# {0: 'dog', 1: 'horse', 2: 'automobile', 3: 'truck', 4: 'frog', 5: 'bird', 6: 'cat', 7: 'ship', 8: 'deer', 9: 'airplane'}

# %%
# Difference in learning rate from resnet50 i did , here default value (to make learning fast here)
new_model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 1 , batch_size = 32)
# Out:
# Epoch 1/1
# 45000/45000 [==============================] - 3407s - loss: 0.7570 - acc: 0.7500

# %%
new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 5 , batch_size = 32)
# Out:
# Epoch 1/5
# 45000/45000 [==============================] - 3372s - loss: 0.4473 - acc: 0.8513
# Epoch 2/5
# 45000/45000 [==============================] - 3367s - loss: 0.3494 - acc: 0.8830
# Epoch 3/5
# 45000/45000 [==============================] - 3367s - loss: 0.2783 - acc: 0.9058
# Epoch 4/5
# 45000/45000 [==============================] - 3367s - loss: 0.2603 - acc: 0.9126
# Epoch 5/5
# 45000/45000 [==============================] - 3367s - loss: 0.1835 - acc: 0.9389

# %%
from keras.models import load_model

new_model.save('entire_inception_ModelNweights.h5')

# new_model = load_model('entire_inception_ModelNweights.h5')

# %%
from get_Train_Validation_set import get_valid_data
valid_data = get_valid_data()

# %%
preds = new_model.evaluate(x = valid_data[0] , y = valid_data[1])
# Out:
# 5000/5000 [==============================] - 157s

# %%
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.409822807431
# Test Accuracy = 0.8796

# %%
# # save model on everytime
# from keras.callbacks import ModelCheckpoint

# filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
# weights.{epoch:02d}-{val_loss:.2f}.hdf5
# checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# callbacks_list = [checkpoint]

# %%
new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 3 , batch_size = 50  )

# new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 3 , batch_size = 50 , callbacks=callbacks_list)

# new_model_details = new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 1 , batch_size = 50)
# plot_model(new_model_details)
# Out:
# Epoch 1/3
# 45000/45000 [==============================] - 3229s - loss: 0.0853 - acc: 0.9711
# Epoch 2/3
# 45000/45000 [==============================] - 3228s - loss: 0.0780 - acc: 0.9734
# Epoch 3/3
# 45000/45000 [==============================] - 3228s - loss: 0.0709 - acc: 0.9760

# %%
preds = new_model.evaluate(x = valid_data[0] , y = valid_data[1])
# Out:
# 5000/5000 [==============================] - 146s

# %%
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 0.341742188016
# Test Accuracy = 0.9066

# %%
new_model.save('entire_inception_ModelNweights.h5')

# %%
class_pred = new_model.predict( valid_data[0])

# %%
print(class_pred)
# Out:
# [[  2.30301889e-11   1.36826999e-11   2.23713892e-09 ...,   2.63193183e-11
#     9.56140167e-11   8.31773973e-12]
#  [  1.48358452e-03   2.52696639e-03   8.94878976e-05 ...,   1.24566839e-04
#     1.29655127e-05   1.08439876e-02]
#  [  5.10841890e-11   1.78925728e-11   2.43450156e-11 ...,   3.33772316e-13
#     1.81772425e-12   9.45629599e-12]
#  ...,
#  [  3.67324901e-05   1.03520243e-07   3.57463191e-11 ...,   8.57247251e-09
#     1.28668475e-07   4.43788579e-08]
#  [  3.32365884e-12   3.45115538e-13   3.41341263e-07 ...,   2.96064034e-10
#     1.79125906e-13   2.97225633e-10]
#  [  8.08785111e-03   6.68901339e-05   2.94698966e-05 ...,   7.48513339e-05
#     6.84321858e-05   2.28062277e-06]]

# %%
import numpy as np
labels_pred = np.argmax(class_pred,axis=1)
print(labels_pred)
# Out:
# [4 5 4 ..., 5 3 4]

# %%
actual = np.argmax(valid_data[1],axis=1)
print(actual)
# Out:
# [4 5 4 ..., 5 3 4]

# %%
correct = (labels_pred == actual)
print(correct)
print("Number of correct predictions: %d" % sum(correct))
# Out:
# [ True  True  True ...,  True  True  True]
# Number of correct predictions: 4533

# %%
num_images = len(correct)
print("Accuracy: %.2f%%" % ((sum(correct)*100)/num_images))
# Out:
# Accuracy: 90.66%

# %%
# print(Y_dict)
import os
Y_dict = {}
i = 0

for v_dirnames in os.listdir("data/valid_data"):
    Y_dict[i] = v_dirnames
    i = i + 1

# %%
print(Y_dict)
# Out:
# {0: 'dog', 1: 'horse', 2: 'automobile', 3: 'truck', 4: 'frog', 5: 'bird', 6: 'cat', 7: 'ship', 8: 'deer', 9: 'airplane'}

# %%
output_ans = [['id','label']]
k = 1
for i in labels_pred:
    output_ans.append([ k , Y_dict[i]])
    k = k +1

# %%
# print(output_ans)

# %%
import csv

with open("output_ans_CIFAR", "w") as csv_file:
        writer = csv.writer(csv_file)
        writer.writerows(output_ans)

# %%
# from get_Train_Validation_set import get_test_set
# test_data = get_test_set()

import os
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from scipy import misc
import random

csv_file = open("Test_output_ans_CIFAR", "w")
Test_output_ans = 'id,label'
test_num_images = 0
csv_file.write(Test_output_ans)
csv_file.write('\n')

import re

numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

for filename in sorted(os.listdir("test/test"), key = numericalSort):
    test_num_images = test_num_images + 1

    img =  misc.imread("test/test/" + filename)
    img = misc.imresize(img , (224,224,3) )
    img = np.reshape(img , (1,224,224,3) )
    Test_class_pred = new_model.predict(img)
    Test_label_pred = int(np.argmax(Test_class_pred,axis=1) )
#     print(Test_label_pred)
    line = str(test_num_images) + ',' + Y_dict[Test_label_pred]
#     print(line)
    csv_file.write(line)
    csv_file.write('\n')
       
csv_file.close()

# %%
# Test_output_ans = [['id','label']]
# k = 1
# for i in Test_labels_pred:
#     Test_output_ans.append([ k , Y_dict[i]])
#     k = k +1

# %%
# with open("Test_output_ans_CIFAR", "w") as csv_file:
#         writer = csv.writer(csv_file)
#         writer.writerows(Test_output_ans)

# %%
p=0

import re

numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

for filename in sorted(os.listdir("test/test") , key = numericalSort):
    print(filename)
    p = p + 1
    if(p == 100):
        break
# Out:
# 1.png
# 2.png
# 3.png
# 4.png
# 5.png
# 6.png
# 7.png
# 8.png
# 9.png
# 10.png
# 11.png
# 12.png
# 13.png
# 14.png
# 15.png
# 16.png
# 17.png
# 18.png
# 19.png
# 20.png
# 21.png
# 22.png
# 23.png
# 24.png
# 25.png
# 26.png
# 27.png
# 28.png
# 29.png
# 30.png
# 31.png
# 32.png
# 33.png
# 34.png
# 35.png
# 36.png
# 37.png
# 38.png
# 39.png
# 40.png
# 41.png
# 42.png
# 43.png
# 44.png
# 45.png
# 46.png
# 47.png
# 48.png
# 49.png
# 50.png
# 51.png
# 52.png
# 53.png
# 54.png
# 55.png
# 56.png
# 57.png
# 58.png
# 59.png
# 60.png
# 61.png
# 62.png
# 63.png
# 64.png
# 65.png
# 66.png
# 67.png
# 68.png
# 69.png
# 70.png
# 71.png
# 72.png
# 73.png
# 74.png
# 75.png
# 76.png
# 77.png
# 78.png
# 79.png
# 80.png
# 81.png
# 82.png
# 83.png
# 84.png
# 85.png
# 86.png
# 87.png
# 88.png
# 89.png
# 90.png
# 91.png
# 92.png
# 93.png
# 94.png
# 95.png
# 96.png
# 97.png
# 98.png
# 99.png
# 100.png
