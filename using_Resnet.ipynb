# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input , decode_predictions

model = ResNet50(weights = 'imagenet')

# %%
print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_6 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472        input_6[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_246 (Activation)      (None, 112, 112, 64)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 55, 55, 64)    0           activation_246[0][0]
# ...

# %%
#  all_amp_layer_weights = model.layers[-1].get_weights()[0]

# %%
# print(all_amp_layer_weights.shape)

# %%
# model.layers.pop()
# model.outputs = [model.layers[-1].output]
# model.layers[-1].outbound_nodes = []
# # model.add(Dense(10, activation='softmax'))
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(model.output_shape)
print(model.summary())
# Out:
# (None, 1000)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_6 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472        input_6[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_246 (Activation)      (None, 112, 112, 64)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
model.layers.pop()
from keras.models import Model
output = model.get_layer('flatten_7').output
output = Dense(output_dim=10, activation='relu')(output) # your newlayer Dense(...)
new_model = Model(model.input, output)
# Out:
# /home/a95/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=10)`
#   after removing the cwd from sys.path.

# %%
new_model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_6 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472        input_6[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_246 (Activation)      (None, 112, 112, 64)  0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)   (None, 55, 55, 64)    0           activation_246[0][0]
# ...

# %%
# from keras.models import Sequential

# # print(model.output_shape[1:])
# top_model = Sequential()
# # x = Dense(4096, activation='relu', name='fc3')

# top_model.add(Dense(10, activation='softmax', input_shape=(2048,) ))

# %%
# output = model.get_layer('avg_pool').output
# output = Flatten()(output)
# output = Dense(output_dim=10000, activation='relu')(output) # your newlayer Dense(...)

# %%
# new_model = Sequential()
# for l in model.layers:
# #     print(l)
#     new_model.add(l)
# new_model.add(top_model)

# %%
for layer in model.layers[:25]:
    layer.trainable = False

# %%
from get_Train_Validation_set import get_train_set
train_data = get_train_set()
# Out:
# (45000, 224, 224, 3)

# %%
print(train_data[0].shape)
# Out:
# (45000, 224, 224, 3)

# %%
optimiser = keras.optimizers.Adam(lr=0.000001)
new_model.compile(optimizer= optimiser, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.fit(x = train_data[0] ,y = train_data[1], epochs = 20 , batch_size = 16)
# Out:
# Epoch 1/20
# 45000/45000 [==============================] - 5204s - loss: 11.1607 - acc: 0.1041
# Epoch 2/20
# 45000/45000 [==============================] - 5164s - loss: 9.2788 - acc: 0.1230
# Epoch 3/20
# 45000/45000 [==============================] - 5166s - loss: 7.9891 - acc: 0.1634
# Epoch 4/20
# 45000/45000 [==============================] - 5281s - loss: 6.8728 - acc: 0.2080
# Epoch 5/20
# 45000/45000 [==============================] - 5190s - loss: 6.4261 - acc: 0.2468
# Epoch 6/20
# 45000/45000 [==============================] - 5163s - loss: 6.2775 - acc: 0.2796
# Epoch 7/20
# 45000/45000 [==============================] - 5164s - loss: 5.6541 - acc: 0.2949
# Epoch 8/20
# 45000/45000 [==============================] - 5164s - loss: 4.3145 - acc: 0.3055
# Epoch 9/20
# 45000/45000 [==============================] - 5163s - loss: 3.8397 - acc: 0.3088
# Epoch 10/20
# 45000/45000 [==============================] - 5164s - loss: 3.7118 - acc: 0.3216
# Epoch 11/20
# ...

# %%
from keras.models import load_model

new_model.save('entire_Resnet_ModelNweights.h5')

# model = load_model('entire_Resnet_ModelNweights.h5')

# %%
model_json = new_model.to_json()
json_file = open("only_Resnet_model.json","w")
json_file.write(model_json)
json_file.close()

# %%
new_model.save_weights("only_Resnet_weights.h5")
print("saved")
# Out:
# saved

# %%
from keras.models import model_from_json
json_file = open("only_Resnet_model.json","r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# %%
loaded_model.load_weights("only_Resnet_weights.h5")

# %%
loaded_model.compile(optimizer= optimiser, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# from get_Train_Validation_set import get_valid_data
# valid_data = get_valid_data()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-110-a6f3959eefb0> in <module>()
#       1 from get_Train_Validation_set import get_valid_data
# ----> 2 valid_data = get_valid_data()
#
# ~/Downloads/DATASET CIFAR 10 | KAGGLE/get_Train_Validation_set.py in get_valid_data()
#      66     #         plt.imshow(v_img)
#      67     #         plt.show()
# ---> 68             v_img = misc.imresize(v_img , (224,224,3) )
#      69             if v_img is not None:
#      70                 v_images.append(v_img)
#
# UnboundLocalError: local variable 'img' referenced before assignment

# %%
import os
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from scipy import misc
import random

i = 0
valid_num_images = 0
v_images = []
v_y = []
v_Y_dict = {}
for v_dirnames in os.listdir("data/valid_data"):
#         print(v_dirnames)
    v_Y_dict[v_dirnames] = i
    for v_filename in os.listdir("data/valid_data/"+ v_dirnames):
        valid_num_images = valid_num_images + 1
        #print(filenames,"\n")
        # img = mpimg.imread("data/train_valid/"+ dirnames + "/" + filename) or  img =  misc.imread("data/train_valid/"+ dirnames + "/" + filename)
        v_img =  misc.imread("data/valid_data/"+ v_dirnames + "/" + v_filename)
#         plt.imshow(v_img)
#         plt.show()
        v_img = misc.imresize(v_img , (224,224,3) )
        if v_img is not None:
            v_images.append(v_img)
            v_y.append(i)
#             print(v_img)
#             print(v_y)

    i = i + 1

v_c = list(zip(v_images, v_y))

random.shuffle(v_c)

v_X,v_Y = zip(*v_c)

validation_set = np.reshape(v_X , (valid_num_images,224,224,3) )
validation_out = keras.utils.to_categorical(v_Y,num_classes=10)

valid_data =  (validation_set,validation_out)

# %%
preds = loaded_model.evaluate(x = valid_data[0] , y = valid_data[1])
# Out:
# 5000/5000 [==============================] - 225s

# %%
print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# Loss = 3.10499865646
# Test Accuracy = 0.4422

# %%
# model.layers.pop()
# model.outputs = [model.layers[-1].output]
# model.layers[-1].outbound_nodes = []
# # model.add(Dense(10, activation='softmax'))
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# print(model.summary())

# %%
# # from keras.models import load_model
# # prev_model = load_model('vgg16.h5')
# from keras.models import Sequential
# from keras.applications.vgg16 import VGG16
# from keras.preprocessing import image
# from keras.applications.vgg16 import preprocess_input
# from keras.layers import Input, Dense, Convolution2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D, Dropout, Flatten, merge, Reshape, Activation

# # print(model.output_shape[1:])
# top_model = Sequential()
# # x = Dense(4096, activation='relu', name='fc3')
# top_model.add(Dense(10, activation='softmax' , input_shape=(2048,)))
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# new_model = Sequential()
# for l in model.layers:
#     new_model.add(l)
# # new_model.add(top_model)
